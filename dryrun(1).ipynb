# %%
# -*- coding: utf-8 -*-
"""dryrun.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1Acc5mazy95XHQKbpEZWmfsNKfqPxNnUi
"""

# -*- coding: utf-8 -*-
"""optimum jugadoos.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1wROuYNN23knJYGA9SLqEz-1-66pYoqa5

#INSTALLATIONS
"""

"""#HEADERS"""
HEADERS = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:89.0) Gecko/20100101 Firefox/89.0', 'Accept-Language':'en-in'}


"""#IMPORTS"""

import csv 
import requests
import time
from bs4 import BeautifulSoup as bs








"""#INPUT FROM BACKEND"""


a=input("enter the product name")
# Out:
# enter the product namezombie apocalypse

# %%
"""#AMAZON DATA EXTRACTION

"""

base="www.amazon.in"
def get_url(search_term):
    template='https://www.amazon.in/s?k={}&ref=nb_sb_noss_2'
    search_term=search_term.replace(' ','+')
    return template.format(search_term)
url=get_url(a)

url_amazon=url
response=requests.get(url, headers=HEADERS)
html=response.content




"""#CREATING SOUP FOR AMAZON"""

soup=bs(html,'html.parser')
item=soup.find_all('div',{'data-component-type':'s-search-result'})
i=0
for i in range(len(item)):
  pp=item[0].find_all('span',{'class':'a-size-medium'})
  pp1=item[0].find_all('span',{'class':'a-size-base-plus'})
  if len(pp)!=0 or len(pp1)!=0 :
    break
  i=i+1


if len(item)>=3:
    
 try:
  price_amazon_0="Rs-"+item[i].find('span', 'a-offscreen').text[1:]
 except:
  price_amazon_0="price not availaible"

 try:
  price_amazon_1="Rs-"+item[i].find('span', 'a-offscreen').text[1:]
 except:
  price_amazon_1="price not availaible"
 try:
  price_amazon_2="Rs-"+item[i].find('span', 'a-offscreen').text[1:]
 except:
  price_amazon_2="price not availaible"




 pp=item[i].find_all('span',{'class':'a-size-medium'})
 try:
  name_amazon_0=pp[0].text
 except:
   pp=item[i].find_all('span',{'class':'a-size-base-plus'})
   name_amazon_0=pp[0].text
 pp=item[i+1].find_all('span',{'class':'a-size-medium'})
 try:
  name_amazon_1=pp[0].text
 except:
   pp=item[i+1].find_all('span',{'class':'a-size-base-plus'})
   name_amazon_1=pp[0].text

 pp=item[i+2].find_all('span',{'class':'a-size-medium'})

 try:
  name_amazon_0=pp[0].text
 except:
   pp=item[i+2].find_all('span',{'class':'a-size-base-plus'})
   name_amazon_2=pp[0].text

 image_tag=item[i].find_all('img',{'class':'s-image'})
 image_amazon_0=image_tag[0].get('src')
 image_tag=item[i+1].find_all('img',{'class':'s-image'})

 image_amazon_1=image_tag[0].get('src')
 image_tag=item[i+2].find_all('img',{'class':'s-image'})

 image_amazon_2=image_tag[0].get('src')


 pp=item[i].find_all('span',{'class':'a-size-base'})
 try:
  rating_amazon=pp[0].text
 except:
   rating_amazon='0'


 rating_amazon_0="("+ rating_amazon + ")"
 pp=item[i+1].find_all('span',{'class':'a-size-base'})

 try:
   rating_amazon=pp[0].text
 except:
   rating_amazon='0'

 
 rating_amazon_1="("+ rating_amazon + ")"
 pp=item[i+2].find_all('span',{'class':'a-size-base'})

 try:
   rating_amazon=pp[0].text
 except:
   rating_amazon='0' 
 rating_amazon_2="("+ rating_amazon + ")"
 pp=item[i].find_all('span',{'class':'a-icon-alt'})
 try:
  star_amazon_0=pp[0].text[0:4]
 except:
  star_amazon_0='0'
 pp=item[i+1].find_all('span',{'class':'a-icon-alt'})

 try:
  star_amazon_1=pp[0].text[0:4]
 except:
  star_amazon_1='0'
 pp=item[i+2].find_all('span',{'class':'a-icon-alt'})

 try:
  star_amazon_2=pp[0].text[0:4]
 except:
  star_amazon_2='0'
elif len(item)==2:
 try:
  price_amazon_0="Rs-"+item[i].find('span', 'a-offscreen').text[1:]
 except:
  price_amazon_0="price not availaible"
 try:
  price_amazon_1="Rs-"+item[i].find('span', 'a-offscreen').text[1:]
 except:
  price_amazon_1="price not availaible"





 pp=item[i].find_all('span',{'class':'a-size-medium'})
 try:
  name_amazon_0=pp[0].text
 except:
   pp=item[i].find_all('span',{'class':'a-size-base-plus'})
   name_amazon_0=pp[0].text
 pp=item[i+1].find_all('span',{'class':'a-size-medium'})
 try:
  name_amazon_1=pp[0].text
 except:
   pp=item[i+1].find_all('span',{'class':'a-size-base-plus'})
   name_amazon_1=pp[0].text


 

 image_tag=item[i+0].find_all('img',{'class':'s-image'})
 image_amazon_0=image_tag[0].get('src')
 image_tag=item[i+1].find_all('img',{'class':'s-image'})


 image_amazon_2=image_tag[0].get('src')


 pp=item[i+0].find_all('span',{'class':'a-size-base'})
 try:
   rating_amazon=pp[0].text
 except:
   rating_amazon='0'
 rating_amazon_0="("+ rating_amazon + ")"
 pp=item[i+1].find_all('span',{'class':'a-size-base'})

 try:
   rating_amazon=pp[0].text
 except:
   rating_amazon='0'
 rating_amazon_1="("+ rating_amazon + ")"

 pp=item[i+0].find_all('span',{'class':'a-icon-alt'})
 try:
  star_amazon_0=pp[0].text[0:4]
 except:
  star_amazon_0='0'
 pp=item[i+1].find_all('span',{'class':'a-icon-alt'})

 try:
  star_amazon_1=pp[0].text[0:4]
 except:
  star_amazon_1='0'

 price_amazon_2="item not found"
 name_amazon_2="item not found"
 image_amazon_2="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_amazon_2="item not found"
 star_amazon_2="item not found"
elif len(item)==1:
 try:
  price_amazon_0="Rs-"+item[i].find('span', 'a-offscreen').text[1:]
 except:
  price_amazon_0="price not availaible"






 pp=item[i].find_all('span',{'class':'a-size-medium'})
 try:
  name_amazon_0=pp[0].text
 except:
   pp=item[i].find_all('span',{'class':'a-size-base-plus'})
   name_amazon_0=pp[0].text



 image_tag=item[i+0].find_all('img',{'class':'s-image'})
 image_amazon_0=image_tag[0].get('src')



 pp=item[i+0].find_all('span',{'class':'a-size-base'})
 try:
   rating_amazon=pp[0].text
 except:
   rating_amazon='0'
 rating_amazon_0="("+ rating_amazon + ")"


 pp=item[i+0].find_all('span',{'class':'a-icon-alt'})
 try:
  star_amazon_0=pp[0].text[0:4]
 except:
  star_amazon_0='0'


 price_amazon_2="item not found"
 name_amazon_2="item not found"
 image_amazon_2="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_amazon_2="item not found"
 star_amazon_2="item not found"
 price_amazon_1="item not found"
 name_amazon_1="item not found"
 image_amazon_1="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_amazon_1="item not found"
 star_amazon_1="item not found"
 
 


else:
  price_amazon_0="item not found"
  name_amazon_0="item not found"
  image_amazon_0="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
  rating_amazon_0="item not found"
  star_amazon_0="item not found"
  price_amazon_2="item not found"
  name_amazon_2="item not found"
  image_amazon_2="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
  rating_amazon_2="item not found"
  star_amazon_2="item not found"
  price_amazon_1="item not found"
  name_amazon_1="item not found"
  image_amazon_1="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
  rating_amazon_1="item not found"
  star_amazon_1="item not found"

# %%
item[0]
# Out:
# <div class="s-result-item s-asin sg-col-0-of-12 sg-col-16-of-20 sg-col sg-col-12-of-16" data-asin="B08R42HGC3" data-component-type="s-search-result" data-index="0" data-uuid="75ab32a6-3bdb-49c2-8fd6-2f9f56fd6bc3"><div class="sg-col-inner">
# <span cel_widget_id="MAIN-SEARCH_RESULTS-0" class="celwidget slot=MAIN template=SEARCH_RESULTS widgetId=search-results">
# ...

# %%
"""#SNAPDEAL EXTRACTION"""

base1="https://www.snapdeal.com/"
def get_url(search_term1):

    template='https://www.snapdeal.com/search?keyword={}&sort=rlvncy'
    search_term1=search_term1.replace(' ','+')
    return template.format(search_term1)
url=get_url(a)
url_snapdeal=url

response=requests.get(url)
html=response.content

"""#CREATING SOUP FOR SNAPDEAL"""

soup1=bs(html,"html.parser")
item=soup1.find_all('div',{'data-js-pos':'0'})
if len(item)>=3:
 atag1=item[0].a
 des=atag1.text.strip()
 url=atag1.get('href')
 price_snapdeal_0="Rs-"+item[0].find('span', 'lfloat product-price').text[5:]

 atag1=item[1].a
 des=atag1.text.strip()
 url=atag1.get('href')
 price_snapdeal_0="Rs-"+item[1].find('span', 'lfloat product-price').text[5:]

 atag1=item[2].a
 des=atag1.text.strip()
 url=atag1.get('href')
 price_snapdeal_2="Rs-"+item[2].find('span', 'lfloat product-price').text[5:]


 pp=item[0].find_all('p',{'class':'product-title'})
 name_snapdeal_0=pp[0].text
 pp=item[1].find_all('p',{'class':'product-title'})

 name_snapdeal_1=pp[0].text
 pp=item[2].find_all('p',{'class':'product-title'})

 name_snapdeal_2=pp[0].text
 pp=item[0].find_all('img',{'class':'product-image'})
 image_snapdeal_0=pp[0].get('src')
 pp=item[1].find_all('img',{'class':'product-image'})

 image_snapdeal_1=pp[0].get('src')
 pp=item[2].find_all('img',{'class':'product-image'})

 image_snapdeal_2=pp[0].get('src')
 pp=item[0].find_all('p',{'class':'product-rating-count'})
 try:
  rating_snapdeal_0=pp[0].text
 except:
  rating_snapdeal_0='0'
 pp=item[1].find_all('p',{'class':'product-rating-count'})

 try:
  rating_snapdeal_1=pp[0].text
 except:
  rating_snapdeal_1='0'
 pp=item[2].find_all('p',{'class':'product-rating-count'})

 try:
  rating_snapdeal_2=pp[0].text
 except:
  rating_snapdeal_2='0'

 pp=item[0].find_all('div',{'class':'filled-stars'})
 try:
  star_snapdeal_0=float(pp[0].get('style')[6:10])/20
 except:
  star_snapdeal_0='0'

 pp=item[1].find_all('div',{'class':'filled-stars'})

 try:
  star_snapdeal_1=float(pp[0].get('style')[6:10])/20
 except:
  star_snapdeal_1='0'

 pp=item[2].find_all('div',{'class':'filled-stars'})

 try:
  star_snapdeal_2=float(pp[0].get('style')[6:10])/20
 except:
  star_snapdeal_2='0'


elif len(item)==2:
 atag1=item[0].a
 des=atag1.text.strip()
 url=atag1.get('href')
 price_snapdeal_0="Rs-"+item[0].find('span', 'lfloat product-price').text[5:]

 atag1=item[1].a
 des=atag1.text.strip()
 url=atag1.get('href')
 price_snapdeal_1="Rs-"+item[1].find('span', 'lfloat product-price').text[5:]




 pp=item[0].find_all('p',{'class':'product-title'})
 name_snapdeal_0=pp[0].text
 pp=item[1].find_all('p',{'class':'product-title'})

 name_snapdeal_1=pp[0].text

 pp=item[0].find_all('img',{'class':'product-image'})
 image_snapdeal_0=pp[0].get('src')
 pp=item[1].find_all('img',{'class':'product-image'})

 

 image_snapdeal_1=pp[0].get('src')
 pp=item[0].find_all('p',{'class':'product-rating-count'})
 try:
  rating_snapdeal_0=pp[0].text
 except:
  rating_snapdeal_0='0'
 pp=item[1].find_all('p',{'class':'product-rating-count'})



 try:
  rating_snapdeal_1=pp[0].text
 except:
  rating_snapdeal_1='0'

 pp=item[0].find_all('div',{'class':'filled-stars'})
 try:
  star_snapdeal_0=float(pp[0].get('style')[6:10])/20
 except:
  star_snapdeal_0='0'

 pp=item[1].find_all('div',{'class':'filled-stars'})

 try:
  star_snapdeal_1=float(pp[0].get('style')[6:10])/20
 except:
  star_snapdeal_1='0'


 price_snapdeal_2="item not found"
 name_snapdeal_2="item not found"
 image_snapdeal_2="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_snapdeal_2="item not found"
 star_snapdeal_2="item not found"

 
elif len(item)==1:
 atag1=item[0].a
 des=atag1.text.strip()
 url=atag1.get('href')
 price_snapdeal_0="Rs-"+item[0].find('span', 'lfloat product-price').text[5:]



 pp=item[0].find_all('p',{'class':'product-title'})
 name_snapdeal_0=pp[0].text


 pp=item[0].find_all('img',{'class':'product-image'})
 image_snapdeal_0=pp[0].get('src')


 pp=item[0].find_all('p',{'class':'product-rating-count'})
 try:
  rating_snapdeal_0=pp[0].text
 except:
  rating_snapdeal_0='0'


 pp=item[0].find_all('div',{'class':'filled-stars'})
 try:
  star_snapdeal_0=float(pp[0].get('style')[6:10])/20
 except:
  star_snapdeal_0='0'



 price_snapdeal_2="item not found"
 name_snapdeal_2="item not found"
 image_snapdeal_2="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_snapdeal_2="item not found"
 star_snapdeal_2="item not found"
 price_snapdeal_1="item not found"
 name_snapdeal_1="item not found"
 image_snapdeal_1="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_snapdeal_1="item not found"
 star_snapdeal_1="item not found"
else:
  price_snapdeal_0="item not found"
  name_snapdeal_0="item not found"
  image_snapdeal_0="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
  rating_snapdeal_0="item not found"
  star_snapdeal_0="item not found"
  price_snapdeal_2="item not found"
  name_snapdeal_2="item not found"
  image_snapdeal_2="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
  rating_snapdeal_2="item not found"
  star_snapdeal_2="item not found"
  price_snapdeal_1="item not found"
  name_snapdeal_1="item not found"
  image_snapdeal_1="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
  rating_snapdeal_1="item not found"
  star_snapdeal_1="item not found"

# %%
"""#DATA EXTRACTION FOR FLIPKART"""

base2="www.flipkart.com"
def get_url(search_term):
    template='https://www.flipkart.com/search?q={}'
    search_term=search_term.replace(' ','+')
    return template.format(search_term)
url=get_url(a)
url_flipkart=url

response=requests.get(url)
html=response.content

"""#CREATING SOUP FOR FLIPKART"""

soup2=bs(html,'html.parser')
results=soup2.find_all('div',{'class':'_4ddWXP'})

if len(results)>=3:

 item=results[0]
 atag3=item.a
 des=atag3.text.strip()
 url=base2+atag3.get('href')
 url1="https://"+url
 response=requests.get(url1)


 html1=response.content
 soup3=bs(html1,'html.parser')
 item=soup3.find_all('div', {'class':'_30jeq3'})
 price_flipkart_0="Rs-"+ item[0].text[1:]

 pp=soup3.find_all('span',{'class':'B_NuCI'})
 name_flipkart_0=pp[0].text

 pp=soup3.find_all('img',{'class':'_396cs4'})
 image_flipkart_0=pp[0].get('src')

 pp=soup3.find_all('span',{'class':'_2_R_DZ'})
 try:
  rating_flipkart_0=pp[0].text
 except:
  rating_flipkart_0='0'

 pp=soup3.find_all('div',{'class':'_3LWZlK'})
 try:
  star_flipkart_0=pp[0].text
 except:
  star_flipkart_0='0'

 item = results[1]
 atag3 = item.a
 des = atag3.text.strip()
 url = base2 + atag3.get('href')
 url1 = "https://" + url
 response = requests.get(url1)

 html1 = response.content
 soup3 = bs(html1, 'html.parser')
 item = soup3.find_all('div', {'class': '_30jeq3'})
 price_flipkart_1 = "Rs-" + item[0].text[1:]

 pp=soup3.find_all('span',{'class':'B_NuCI'})
 name_flipkart_1= pp[0].text

 pp = soup3.find_all('img', {'class': '_396cs4'})
 image_flipkart_1 = pp[0].get('src')

 pp = soup3.find_all('span', {'class': '_2_R_DZ'})
 try:
  rating_flipkart_1=pp[0].text
 except:
  rating_flipkart_1='0'

 pp = soup3.find_all('div', {'class': '_3LWZlK'})
 try:
  star_flipkart_1=pp[0].text
 except:
  star_flipkart_1='0'

 item = results[2]
 atag3 = item.a
 des = atag3.text.strip()
 url = base2 + atag3.get('href')
 url1 = "https://" + url
 response = requests.get(url1)

 html1 = response.content
 soup3 = bs(html1, 'html.parser')
 item = soup3.find_all('div', {'class': '_30jeq3'})
 price_flipkart_2= "Rs-" + item[0].text[1:]

 pp=soup3.find_all('span',{'class':'B_NuCI'})
 name_flipkart_2= pp[0].text

 pp = soup3.find_all('img', {'class': '_396cs4'})
 image_flipkart_2 = pp[0].get('src')

 pp = soup3.find_all('span', {'class': '_2_R_DZ'})
 try:
  rating_flipkart_2=pp[0].text
 except:
  rating_flipkart_2='0'

 pp = soup3.find_all('div', {'class': '_3LWZlK'})
 try:
  star_flipkart_2=pp[0].text
 except:
  star_flipkart_2='0'

elif len(item)==2:
 item=results[0]
 atag3=item.a
 des=atag3.text.strip()
 url=base2+atag3.get('href')
 url1="https://"+url
 response=requests.get(url1)


 html1=response.content
 soup3=bs(html1,'html.parser')
 item=soup3.find_all('div', {'class':'_30jeq3'})
 price_flipkart_0="Rs-"+ item[0].text[1:]

 pp=soup3.find_all('span',{'class':'B_NuCI'})
 name_flipkart_0=pp[0].text

 pp=soup3.find_all('img',{'class':'_396cs4'})
 image_flipkart_0=pp[0].get('src')

 pp=soup3.find_all('span',{'class':'_2_R_DZ'})
 try:
  rating_flipkart_0=pp[0].text
 except:
  rating_flipkart_0='0'



 pp=soup3.find_all('div',{'class':'_3LWZlK'})
 try:
  star_flipkart_0=pp[0].text
 except:
  star_flipkart_0='0'

 item = results[1]
 atag3 = item.a
 des = atag3.text.strip()
 url = base2 + atag3.get('href')
 url1 = "https://" + url
 response = requests.get(url1)

 html1 = response.content
 soup3 = bs(html1, 'html.parser')
 item = soup3.find_all('div', {'class': '_30jeq3'})
 price_flipkart_1 = "Rs-" + item[0].text[1:]

 pp=soup3.find_all('span',{'class':'B_NuCI'})
 name_flipkart_1= pp[0].text

 pp = soup3.find_all('img', {'class': '_396cs4'})
 image_flipkart_1 = pp[0].get('src')

 pp = soup3.find_all('span', {'class': '_2_R_DZ'})
 try:
  rating_flipkart_1=pp[0].text
 except:
  rating_flipkart_1='0'

 pp = soup3.find_all('div', {'class': '_3LWZlK'})
 try:
  star_flipkart_1=pp[0].text
 except:
  star_flipkart_1='0'
 price_flipkart_2="item not found"
 name_flipkart_2="item not found"
 image_flipkart_2="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_flipkart_2="item not found"
 star_flipkart_2="item not found"
elif len(item)==1:
 item=results[0]
 atag3=item.a
 des=atag3.text.strip()
 url=base2+atag3.get('href')
 url1="https://"+url
 response=requests.get(url1)


 html1=response.content
 soup3=bs(html1,'html.parser')
 item=soup3.find_all('div', {'class':'_30jeq3'})
 price_flipkart_0="Rs-"+ item[0].text[1:]

 pp=soup3.find_all('span',{'class':'B_NuCI'})
 name_flipkart_0=pp[0].text

 pp=soup3.find_all('img',{'class':'_396cs4'})
 image_flipkart_0=pp[0].get('src')

 pp=soup3.find_all('span',{'class':'_2_R_DZ'})
 try:
  rating_flipkart_0=pp[0].text
 except:
  rating_flipkart_0='0'



 pp=soup3.find_all('div',{'class':'_3LWZlK'})
 try:
  star_flipkart_0=pp[0].text
 except:
  star_flipkart_0='0'
 price_flipkart_2="item not found"
 name_flipkart_2="item not found"
 image_flipkart_2="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_flipkart_2="item not found"
 star_flipkart_2="item not found"
 price_flipkart_1="item not found"
 name_flipkart_1="item not found"
 image_flipkart_1="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_flipkart_1="item not found"
 star_flipkart_1="item not found"
else:

 price_flipkart_2="item not found"
 name_flipkart_2="item not found"
 image_flipkart_2="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_flipkart_2="item not found"
 star_flipkart_2="item not found"
 price_flipkart_1="item not found"
 name_flipkart_1="item not found"
 image_flipkart_1="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_flipkart_1="item not found"
 star_flipkart_1="item not found"
 price_flipkart_0="item not found"
 name_flipkart_0="item not found"
 image_flipkart_0="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_flipkart_0="item not found"
 star_flipkart_0="item not found"

# %%
results[1]

# %%
html1
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.ab0c37.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" sizes="72x72" href="/apple-touch-icon-72x72.png"/><link rel="app
# ...

# %%
print(price_amazon_0)
print(name_amazon_0)
print(image_amazon_0)
print(rating_amazon_0)
print(star_amazon_0)
print(price_snapdeal_0)
print(name_snapdeal_0)
print(image_snapdeal_0)
print(rating_snapdeal_0)
print(star_snapdeal_0)
print(price_flipkart_0)
print(name_flipkart_0)
print(image_flipkart_0)
print(rating_flipkart_0)
print(star_flipkart_0)

print(price_amazon_1)
print(name_amazon_1)
print(image_amazon_1)
print(rating_amazon_1)
print(star_amazon_1)
print(price_snapdeal_1)
print(name_snapdeal_1)
print(image_snapdeal_1)
print(rating_snapdeal_1)
print(star_snapdeal_1)
print(price_flipkart_1)
print(name_flipkart_1)
print(image_flipkart_1)
print(rating_flipkart_1)
print(star_flipkart_1)

print(price_amazon_2)
print(name_amazon_2)
print(image_amazon_2)
print(rating_amazon_2)
print(star_amazon_2)
print(price_snapdeal_2)
print(name_snapdeal_2)
print(image_snapdeal_2)
print(rating_snapdeal_2)
print(star_snapdeal_2)
print(price_flipkart_2)
print(name_flipkart_2)
print(image_flipkart_2)
print(rating_flipkart_2)
print(star_flipkart_2)
# Out:
# price not availaible
# Resident Evil: Apocalypse
# https://m.media-amazon.com/images/I/81P+63S4B7L._AC_UY218_.jpg
# (2015)
# 0
# Rs-1,070
# Call of Duty WWII Game, PS4, PC, Xbox One, Zombies, Reddit, Tips Guide Unofficial
# https://n4.sdlcdn.com/imgs/i/h/1/230X258_sharpened/Call-of-Duty-WWII-Game-SDL647953371-1-f597e.jpg
# (2)
# 2.5
# Rs-282
# Diary of a Minecraft Zombie Book 9: Zombie's Birthday Apocalypse  (English, Hardcover, Zack Zombie)
# https://rukminim1.flixcart.com/image/416/416/k65d18w0/book/8/3/8/diary-of-a-minecraft-zombie-book-9-zombie-s-birthday-apocalypse-original-imafzzczbfkukvsm.jpeg?q=70
# 18 Ratings & 0 Reviews
# 4.7
# price not availaible
# Zombie Apocalypse 2021
# https://m.media-amazon.com/images/I/61-WW0AdQLS._AC_UY218_.jpg
# (by )
# 0
# item not found
# item not found
# ...

# %%
print(url_amazon)
# Out:
# https://www.amazon.in/s?k=zombie+apocalypse&ref=nb_sb_noss_2

# %%
print(url_flipkart)
# Out:
# https://www.flipkart.com/search?q=boat+basshead+100

# %%
print(url_snapdeal)
# Out:
# https://www.snapdeal.com/search?keyword=boat+basshead+100&sort=rlvncy

# %%
item[0]
# Out:
# <div class="sg-col-4-of-12 s-result-item s-asin sg-col-4-of-16 AdHolder sg-col sg-col-4-of-20" data-asin="B00QKD79QE" data-component-type="s-search-result" data-index="1" data-uuid="81631681-4b25-41ed-a24d-c6e35d50f623"><div class="sg-col-inner">
# <span cel_widget_id="MAIN-SEARCH_RESULTS-1" class="celwidget slot=MAIN template=SEARCH_RESULTS widgetId=search-results">
# <div class="rush-component s-expand-height" data-component-props='{"percentageShownToFire":"50","batchable":true,"requiredElementSelector":".s-image","url":"https://www.amazon.in/gp/sponsored-products/logging/log-action.html?qualifier=1626500917&amp;id=8011909998449684&amp;widgetName=sp_atf&amp;adId=20068143522702&amp;eventType=1&amp;adIndex=0"}' data-component-type="s-impression-logger">
# <div class="rush-component s-expand-height" data-component-type="sp-sponsored-result">
# ...

# %%
item[3]
# Out:
# <div class="sg-col-4-of-12 s-result-item s-asin sg-col-4-of-16 AdHolder sg-col sg-col-4-of-20" data-asin="B01BGX82G8" data-component-type="s-search-result" data-index="4" data-uuid="f45eb2ab-7cd9-4820-88f4-7a07010ec869"><div class="sg-col-inner">
# <span cel_widget_id="MAIN-SEARCH_RESULTS-4" class="celwidget slot=MAIN template=SEARCH_RESULTS widgetId=search-results">
# <div class="rush-component s-expand-height" data-component-props='{"percentageShownToFire":"50","batchable":true,"requiredElementSelector":".s-image","url":"https://www.amazon.in/gp/sponsored-products/logging/log-action.html?qualifier=1626500917&amp;id=8011909998449684&amp;widgetName=sp_atf&amp;adId=20063625030006&amp;eventType=1&amp;adIndex=3"}' data-component-type="s-impression-logger">
# <div class="rush-component s-expand-height" data-component-type="sp-sponsored-result">
# ...

# %%
item[6]
# Out:
# <div class="sg-col-4-of-12 s-result-item s-asin sg-col-4-of-16 sg-col sg-col-4-of-20" data-asin="B08VXR74Q2" data-component-type="s-search-result" data-index="7" data-uuid="a7b25064-d2f7-4200-b00c-a3d14cb8afa0"><div class="sg-col-inner">
# <span cel_widget_id="MAIN-SEARCH_RESULTS-7" class="celwidget slot=MAIN template=SEARCH_RESULTS widgetId=search-results">
# ...

# %%
i
# Out:
# 60

# %%
 pp=item[6].find_all('span',{'class':'a-size-medium'})
 name_amazon_0=pp[0].text
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-12f6e2837e0d> in <module>()
#       1 pp=item[6].find_all('span',{'class':'a-size-medium'})
# ----> 2 name_amazon_0=pp[0].text
#
# IndexError: list index out of range

# %%
"""#AMAZON DATA EXTRACTION

"""

base="www.amazon.in"
def get_url(search_term):
    template='https://www.amazon.in/s?k={}&ref=nb_sb_noss_2'
    search_term=search_term.replace(' ','+')
    return template.format(search_term)
url=get_url(a)

url_amazon=url
response=requests.get(url, headers=HEADERS)
html=response.content




"""#CREATING SOUP FOR AMAZON"""

soup=bs(html,'html.parser')
item=soup.find_all('div',{'data-component-type':'s-search-result'})
i=0
for i in range(len(item)):
  pp=item[0].find_all('span',{'class':'a-size-medium'})
  pp1=item[0].find_all('span',{'class':'a-size-base-plus'})
  if len(pp)!=0 or len(pp1)!=0 :
    break
  i=i+1


if len(item)>=3:
    

 price_amazon_0="Rs-"+item[i].find('span', 'a-offscreen').text[1:]

 price_amazon_1="Rs-"+item[i+1].find('span', 'a-offscreen').text[1:]

 price_amazon_2="Rs-"+item[i+2].find('span', 'a-offscreen').text[1:]




 pp=item[i].find_all('span',{'class':'a-size-medium'})
 try:
  name_amazon_0=pp[0].text
 except:
   pp=item[i].find_all('span',{'class':'a-size-base-plus'})
   name_amazon_0=pp[0].text
 pp=item[i+1].find_all('span',{'class':'a-size-medium'})
 try:
  name_amazon_1=pp[0].text
 except:
   pp=item[i+1].find_all('span',{'class':'a-size-base-plus'})
   name_amazon_1=pp[0].text

 pp=item[i+2].find_all('span',{'class':'a-size-medium'})

 try:
  name_amazon_0=pp[0].text
 except:
   pp=item[i+2].find_all('span',{'class':'a-size-base-plus'})
   name_amazon_2=pp[0].text

 image_tag=item[i].find_all('img',{'class':'s-image'})
 image_amazon_0=image_tag[0].get('src')
 image_tag=item[i+1].find_all('img',{'class':'s-image'})

 image_amazon_1=image_tag[0].get('src')
 image_tag=item[i+2].find_all('img',{'class':'s-image'})

 image_amazon_2=image_tag[0].get('src')


 pp=item[i].find_all('span',{'class':'a-size-base'})
 rating_amazon=pp[0].text
 rating_amazon_0="("+ rating_amazon + ")"
 pp=item[i+1].find_all('span',{'class':'a-size-base'})

 rating_amazon=pp[0].text
 rating_amazon_1="("+ rating_amazon + ")"
 pp=item[i+2].find_all('span',{'class':'a-size-base'})

 rating_amazon=pp[0].text
 rating_amazon_2="("+ rating_amazon + ")"
 pp=item[i].find_all('span',{'class':'a-icon-alt'})
 star_amazon_0=pp[0].text[0:4]
 pp=item[i+1].find_all('span',{'class':'a-icon-alt'})

 star_amazon_1=pp[0].text[0:4]
 pp=item[i+2].find_all('span',{'class':'a-icon-alt'})

 star_amazon_2=pp[0].text[0:4]
elif len(item)==2:
 price_amazon_0="Rs-"+item[i+0].find('span', 'a-offscreen').text[1:]

 price_amazon_1="Rs-"+item[i+1].find('span', 'a-offscreen').text[1:]





 pp=item[i].find_all('span',{'class':'a-size-medium'})
 try:
  name_amazon_0=pp[0].text
 except:
   pp=item[i].find_all('span',{'class':'a-size-base-plus'})
   name_amazon_0=pp[0].text
 pp=item[i+1].find_all('span',{'class':'a-size-medium'})
 try:
  name_amazon_1=pp[0].text
 except:
   pp=item[i+1].find_all('span',{'class':'a-size-base-plus'})
   name_amazon_1=pp[0].text


 

 image_tag=item[i+0].find_all('img',{'class':'s-image'})
 image_amazon_0=image_tag[0].get('src')
 image_tag=item[i+1].find_all('img',{'class':'s-image'})


 image_amazon_2=image_tag[0].get('src')


 pp=item[i+0].find_all('span',{'class':'a-size-base'})
 rating_amazon=pp[0].text
 rating_amazon_0="("+ rating_amazon + ")"
 pp=item[i+1].find_all('span',{'class':'a-size-base'})

 rating_amazon=pp[0].text
 rating_amazon_1="("+ rating_amazon + ")"

 pp=item[i+0].find_all('span',{'class':'a-icon-alt'})
 star_amazon_0=pp[0].text[0:4]
 pp=item[i+1].find_all('span',{'class':'a-icon-alt'})

 star_amazon_1=pp[0].text[0:4]

 price_amazon_2="item not found"
 name_amazon_2="item not found"
 image_amazon_2="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_amazon_2="item not found"
 star_amazon_2="item not found"
elif len(item)==1:
 price_amazon_0="Rs-"+item[i+0].find('span', 'a-offscreen').text[1:]






 pp=item[i].find_all('span',{'class':'a-size-medium'})
 try:
  name_amazon_0=pp[0].text
 except:
   pp=item[i].find_all('span',{'class':'a-size-base-plus'})
   name_amazon_0=pp[0].text



 image_tag=item[i+0].find_all('img',{'class':'s-image'})
 image_amazon_0=image_tag[0].get('src')



 pp=item[i+0].find_all('span',{'class':'a-size-base'})
 rating_amazon=pp[0].text
 rating_amazon_0="("+ rating_amazon + ")"


 pp=item[i+0].find_all('span',{'class':'a-icon-alt'})
 star_amazon_0=pp[0].text[0:4]

 price_amazon_2="item not found"
 name_amazon_2="item not found"
 image_amazon_2="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_amazon_2="item not found"
 star_amazon_2="item not found"
 price_amazon_1="item not found"
 name_amazon_1="item not found"
 image_amazon_1="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_amazon_1="item not found"
 star_amazon_1="item not found"
 
 


else:
  price_amazon_0="item not found"
  name_amazon_0="item not found"
  image_amazon_0="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
  rating_amazon_0="item not found"
  star_amazon_0="item not found"
  price_amazon_2="item not found"
  name_amazon_2="item not found"
  image_amazon_2="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
  rating_amazon_2="item not found"
  star_amazon_2="item not found"
  price_amazon_1="item not found"
  name_amazon_1="item not found"
  image_amazon_1="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
  rating_amazon_1="item not found"
  star_amazon_1="item not found"




"""#SNAPDEAL EXTRACTION"""

base1="https://www.snapdeal.com/"
def get_url(search_term1):

    template='https://www.snapdeal.com/search?keyword={}&sort=rlvncy'
    search_term1=search_term1.replace(' ','+')
    return template.format(search_term1)
url=get_url(a)
url_snapdeal=url

response=requests.get(url)
html=response.content

"""#CREATING SOUP FOR SNAPDEAL"""

soup1=bs(html,"html.parser")
item=soup1.find_all('div',{'data-js-pos':'0'})
if len(item)>=3:
 atag1=item[0].a
 des=atag1.text.strip()
 url=atag1.get('href')
 price_snapdeal_0="Rs-"+item[0].find('span', 'lfloat product-price').text[5:]

 atag1=item[1].a
 des=atag1.text.strip()
 url=atag1.get('href')
 price_snapdeal_0="Rs-"+item[1].find('span', 'lfloat product-price').text[5:]

 atag1=item[2].a
 des=atag1.text.strip()
 url=atag1.get('href')
 price_snapdeal_2="Rs-"+item[2].find('span', 'lfloat product-price').text[5:]


 pp=item[0].find_all('p',{'class':'product-title'})
 name_snapdeal_0=pp[0].text
 pp=item[1].find_all('p',{'class':'product-title'})

 name_snapdeal_1=pp[0].text
 pp=item[2].find_all('p',{'class':'product-title'})

 name_snapdeal_2=pp[0].text
 pp=item[0].find_all('img',{'class':'product-image'})
 image_snapdeal_0=pp[0].get('src')
 pp=item[1].find_all('img',{'class':'product-image'})

 image_snapdeal_1=pp[0].get('src')
 pp=item[2].find_all('img',{'class':'product-image'})

 image_snapdeal_2=pp[0].get('src')
 pp=item[0].find_all('p',{'class':'product-rating-count'})
 rating_snapdeal_0=pp[0].text
 pp=item[1].find_all('p',{'class':'product-rating-count'})

 rating_snapdeal_1=pp[0].text
 pp=item[2].find_all('p',{'class':'product-rating-count'})

 rating_snapdeal_2=pp[0].text

 pp=item[0].find_all('div',{'class':'filled-stars'})
 star_snapdeal_0=float(pp[0].get('style')[6:10])/20
 pp=item[1].find_all('div',{'class':'filled-stars'})

 star_snapdeal_1=float(pp[0].get('style')[6:10])/20
 pp=item[2].find_all('div',{'class':'filled-stars'})

 star_snapdeal_2=float(pp[0].get('style')[6:10])/20

elif len(item)==2:
 atag1=item[0].a
 des=atag1.text.strip()
 url=atag1.get('href')
 price_snapdeal_0="Rs-"+item[0].find('span', 'lfloat product-price').text[5:]

 atag1=item[1].a
 des=atag1.text.strip()
 url=atag1.get('href')
 price_snapdeal_0="Rs-"+item[1].find('span', 'lfloat product-price').text[5:]




 pp=item[0].find_all('p',{'class':'product-title'})
 name_snapdeal_0=pp[0].text
 pp=item[1].find_all('p',{'class':'product-title'})

 name_snapdeal_1=pp[0].text

 pp=item[0].find_all('img',{'class':'product-image'})
 image_snapdeal_0=pp[0].get('src')
 pp=item[1].find_all('img',{'class':'product-image'})

 

 image_snapdeal_2=pp[0].get('src')
 pp=item[0].find_all('p',{'class':'product-rating-count'})
 rating_snapdeal_0=pp[0].text
 pp=item[1].find_all('p',{'class':'product-rating-count'})



 rating_snapdeal_2=pp[0].text

 pp=item[0].find_all('div',{'class':'filled-stars'})
 star_snapdeal_0=float(pp[0].get('style')[6:10])/20
 pp=item[1].find_all('div',{'class':'filled-stars'})

 star_snapdeal_1=float(pp[0].get('style')[6:10])/20


 price_snapdeal_2="item not found"
 name_snapdeal_2="item not found"
 image_snapdeal_2="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_snapdeal_2="item not found"
 star_snapdeal_2="item not found"

 
elif len(item)==1:
 atag1=item[0].a
 des=atag1.text.strip()
 url=atag1.get('href')
 price_snapdeal_0="Rs-"+item[0].find('span', 'lfloat product-price').text[5:]



 pp=item[0].find_all('p',{'class':'product-title'})
 name_snapdeal_0=pp[0].text


 pp=item[0].find_all('img',{'class':'product-image'})
 image_snapdeal_0=pp[0].get('src')


 pp=item[0].find_all('p',{'class':'product-rating-count'})
 rating_snapdeal_0=pp[0].text


 pp=item[0].find_all('div',{'class':'filled-stars'})
 star_snapdeal_0=float(pp[0].get('style')[6:10])/20




 price_snapdeal_2="item not found"
 name_snapdeal_2="item not found"
 image_snapdeal_2="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_snapdeal_2="item not found"
 star_snapdeal_2="item not found"
 price_snapdeal_1="item not found"
 name_snapdeal_1="item not found"
 image_snapdeal_1="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_snapdeal_1="item not found"
 star_snapdeal_1="item not found"
else:
  price_snapdeal_0="item not found"
  name_snapdeal_0="item not found"
  image_snapdeal_0="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
  rating_snapdeal_0="item not found"
  star_snapdeal_0="item not found"
  price_snapdeal_2="item not found"
  name_snapdeal_2="item not found"
  image_snapdeal_2="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
  rating_snapdeal_2="item not found"
  star_snapdeal_2="item not found"
  price_snapdeal_1="item not found"
  name_snapdeal_1="item not found"
  image_snapdeal_1="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
  rating_snapdeal_1="item not found"
  star_snapdeal_1="item not found"











"""#DATA EXTRACTION FOR FLIPKART"""

base2="www.flipkart.com"
def get_url(search_term):
    template='https://www.flipkart.com/search?q={}'
    search_term=search_term.replace(' ','+')
    return template.format(search_term)
url=get_url(a)
url_flipkart=url

response=requests.get(url)
html=response.content

"""#CREATING SOUP FOR FLIPKART"""

soup2=bs(html,'html.parser')
results=soup2.find_all('div',{'class':'_13oc-S'})

if len(results)>=3:

 item=results[0]
 atag3=item.a
 des=atag3.text.strip()
 url=base2+atag3.get('href')
 url1="https://"+url
 response=requests.get(url1)


 html1=response.content
 soup3=bs(html1,'html.parser')
 item=soup3.find_all('div', {'class':'_30jeq3'})
 price_flipkart_0="Rs-"+ item[0].text[1:]

 pp=soup3.find_all('a',{'class':'s1Q9rs'})
 name_flipkart_0=pp[0].text

 pp=soup3.find_all('img',{'class':'_396cs4'})
 image_flipkart_0=pp[0].get('src')

 pp=soup3.find_all('span',{'class':'_2_R_DZ'})
 rating_flipkart_0=pp[0].text



 pp=soup3.find_all('div',{'class':'_3LWZlK'})
 star_flipkart_0=pp[0].text

 item = results[1]
 atag3 = item.a
 des = atag3.text.strip()
 url = base2 + atag3.get('href')
 url1 = "https://" + url
 response = requests.get(url1)

 html1 = response.content
 soup3 = bs(html1, 'html.parser')
 item = soup3.find_all('div', {'class': '_30jeq3'})
 price_flipkart_1 = "Rs-" + item[0].text[1:]

 pp = soup3.find_all('a', {'class': 's1Q9rs'})
 name_flipkart_1= pp[0].text

 pp = soup3.find_all('img', {'class': '_396cs4'})
 image_flipkart_1 = pp[0].get('src')

 pp = soup3.find_all('span', {'class': '_2_R_DZ'})
 rating_flipkart_1 = pp[0].text

 pp = soup3.find_all('div', {'class': '_3LWZlK'})
 star_flipkart_1 = pp[0].text

 item = results[2]
 atag3 = item.a
 des = atag3.text.strip()
 url = base2 + atag3.get('href')
 url1 = "https://" + url
 response = requests.get(url1)

 html1 = response.content
 soup3 = bs(html1, 'html.parser')
 item = soup3.find_all('div', {'class': '_30jeq3'})
 price_flipkart_2= "Rs-" + item[0].text[1:]

 pp = soup3.find_all('a', {'class': 's1Q9rs'})
 name_flipkart_2= pp[0].text

 pp = soup3.find_all('img', {'class': '_396cs4'})
 image_flipkart_2 = pp[0].get('src')

 pp = soup3.find_all('span', {'class': '_2_R_DZ'})
 rating_flipkart_2 = pp[0].text

 pp = soup3.find_all('div', {'class': '_3LWZlK'})
 star_flipkart_2 = pp[0].text

elif len(item)==2:
 item=results[0]
 atag3=item.a
 des=atag3.text.strip()
 url=base2+atag3.get('href')
 url1="https://"+url
 response=requests.get(url1)


 html1=response.content
 soup3=bs(html1,'html.parser')
 item=soup3.find_all('div', {'class':'_30jeq3'})
 price_flipkart_0="Rs-"+ item[0].text[1:]

 pp=soup3.find_all('a',{'class':'s1Q9rs'})
 name_flipkart_0=pp[0].text

 pp=soup3.find_all('img',{'class':'_396cs4'})
 image_flipkart_0=pp[0].get('src')

 pp=soup3.find_all('span',{'class':'_2_R_DZ'})
 rating_flipkart_0=pp[0].text



 pp=soup3.find_all('div',{'class':'_3LWZlK'})
 star_flipkart_0=pp[0].text

 item = results[1]
 atag3 = item.a
 des = atag3.text.strip()
 url = base2 + atag3.get('href')
 url1 = "https://" + url
 response = requests.get(url1)

 html1 = response.content
 soup3 = bs(html1, 'html.parser')
 item = soup3.find_all('div', {'class': '_30jeq3'})
 price_flipkart_1 = "Rs-" + item[0].text[1:]

 pp = soup3.find_all('a', {'class': 's1Q9rs'})
 name_flipkart_1= pp[0].text

 pp = soup3.find_all('img', {'class': '_396cs4'})
 image_flipkart_1 = pp[0].get('src')

 pp = soup3.find_all('span', {'class': '_2_R_DZ'})
 rating_flipkart_1 = pp[0].text

 pp = soup3.find_all('div', {'class': '_3LWZlK'})
 star_flipkart_1 = pp[0].text
 price_flipkart_2="item not found"
 name_flipkart_2="item not found"
 image_flipkart_2="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_flipkart_2="item not found"
 star_flipkart_2="item not found"
elif len(item)==1:
 item=results[0]
 atag3=item.a
 des=atag3.text.strip()
 url=base2+atag3.get('href')
 url1="https://"+url
 response=requests.get(url1)


 html1=response.content
 soup3=bs(html1,'html.parser')
 item=soup3.find_all('div', {'class':'_30jeq3'})
 price_flipkart_0="Rs-"+ item[0].text[1:]

 pp=soup3.find_all('a',{'class':'s1Q9rs'})
 name_flipkart_0=pp[0].text

 pp=soup3.find_all('img',{'class':'_396cs4'})
 image_flipkart_0=pp[0].get('src')

 pp=soup3.find_all('span',{'class':'_2_R_DZ'})
 rating_flipkart_0=pp[0].text



 pp=soup3.find_all('div',{'class':'_3LWZlK'})
 star_flipkart_0=pp[0].text
 price_flipkart_2="item not found"
 name_flipkart_2="item not found"
 image_flipkart_2="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_flipkart_2="item not found"
 star_flipkart_2="item not found"
 price_flipkart_1="item not found"
 name_flipkart_1="item not found"
 image_flipkart_1="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_flipkart_1="item not found"
 star_flipkart_1="item not found"
else:

 price_flipkart_2="item not found"
 name_flipkart_2="item not found"
 image_flipkart_2="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_flipkart_2="item not found"
 star_flipkart_2="item not found"
 price_flipkart_1="item not found"
 name_flipkart_1="item not found"
 image_flipkart_1="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_flipkart_1="item not found"
 star_flipkart_1="item not found"
 price_flipkart_0="item not found"
 name_flipkart_0="item not found"
 image_flipkart_0="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_flipkart_0="item not found"
 star_flipkart_0="item not found"





print(price_amazon_0)
print(name_amazon_0)
print(image_amazon_0)
print(rating_amazon_0)
print(star_amazon_0)
print(price_snapdeal_0)
print(name_snapdeal_0)
print(image_snapdeal_0)
print(rating_snapdeal_0)
print(star_snapdeal_0)
print(price_flipkart_0)
print(name_flipkart_0)
print(image_flipkart_0)
print(rating_flipkart_0)
print(star_flipkart_0)

print(price_amazon_1)
print(name_amazon_1)
print(image_amazon_1)
print(rating_amazon_1)
print(star_amazon_1)
print(price_snapdeal_1)
print(name_snapdeal_1)
print(image_snapdeal_1)
print(rating_snapdeal_1)
print(star_snapdeal_1)
print(price_flipkart_1)
print(name_flipkart_1)
print(image_flipkart_1)
print(rating_flipkart_1)
print(star_flipkart_1)

print(price_amazon_2)
print(name_amazon_2)
print(image_amazon_2)
print(rating_amazon_2)
print(star_amazon_2)
print(price_snapdeal_2)
print(name_snapdeal_2)
print(image_snapdeal_2)
print(rating_snapdeal_2)
print(star_snapdeal_2)
print(price_flipkart_2)
print(name_flipkart_2)
print(image_flipkart_2)
print(rating_flipkart_2)
print(star_flipkart_2)
# Out:
# enter the product nameyamaha guitar
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-4be2b61c4f23> in <module>()
#     492
#     493  pp = soup3.find_all('a', {'class': 's1Q9rs'})
# --> 494  name_flipkart_1= pp[0].text
#     495
#     496  pp = soup3.find_all('img', {'class': '_396cs4'})
#
# IndexError: list index out of range

# %%
"""#AMAZON DATA EXTRACTION

"""

base="www.amazon.in"
def get_url(search_term):
    template='https://www.amazon.in/s?k={}&ref=nb_sb_noss_2'
    search_term=search_term.replace(' ','+')
    return template.format(search_term)
url=get_url(a)

url_amazon=url
response=requests.get(url, headers=HEADERS)
html=response.content




"""#CREATING SOUP FOR AMAZON"""

soup=bs(html,'html.parser')
item=soup.find_all('div',{'data-component-type':'s-search-result'})
i=0
for i in range(len(item)):
  pp=item[0].find_all('span',{'class':'a-size-medium'})
  pp1=item[0].find_all('span',{'class':'a-size-base-plus'})
  if len(pp)!=0 or len(pp1)!=0 :
    break
  i=i+1


if len(item)>=3:
    

 price_amazon_0="Rs-"+item[i].find('span', 'a-offscreen').text[1:]

 price_amazon_1="Rs-"+item[i+1].find('span', 'a-offscreen').text[1:]

 price_amazon_2="Rs-"+item[i+2].find('span', 'a-offscreen').text[1:]




 pp=item[i].find_all('span',{'class':'a-size-medium'})
 try:
  name_amazon_0=pp[0].text
 except:
   pp=item[i].find_all('span',{'class':'a-size-base-plus'})
   name_amazon_0=pp[0].text
 pp=item[i+1].find_all('span',{'class':'a-size-medium'})
 try:
  name_amazon_1=pp[0].text
 except:
   pp=item[i+1].find_all('span',{'class':'a-size-base-plus'})
   name_amazon_1=pp[0].text

 pp=item[i+2].find_all('span',{'class':'a-size-medium'})

 try:
  name_amazon_0=pp[0].text
 except:
   pp=item[i+2].find_all('span',{'class':'a-size-base-plus'})
   name_amazon_2=pp[0].text

 image_tag=item[i].find_all('img',{'class':'s-image'})
 image_amazon_0=image_tag[0].get('src')
 image_tag=item[i+1].find_all('img',{'class':'s-image'})

 image_amazon_1=image_tag[0].get('src')
 image_tag=item[i+2].find_all('img',{'class':'s-image'})

 image_amazon_2=image_tag[0].get('src')


 pp=item[i].find_all('span',{'class':'a-size-base'})
 rating_amazon=pp[0].text
 rating_amazon_0="("+ rating_amazon + ")"
 pp=item[i+1].find_all('span',{'class':'a-size-base'})

 rating_amazon=pp[0].text
 rating_amazon_1="("+ rating_amazon + ")"
 pp=item[i+2].find_all('span',{'class':'a-size-base'})

 rating_amazon=pp[0].text
 rating_amazon_2="("+ rating_amazon + ")"
 pp=item[i].find_all('span',{'class':'a-icon-alt'})
 star_amazon_0=pp[0].text[0:4]
 pp=item[i+1].find_all('span',{'class':'a-icon-alt'})

 star_amazon_1=pp[0].text[0:4]
 pp=item[i+2].find_all('span',{'class':'a-icon-alt'})

 star_amazon_2=pp[0].text[0:4]
elif len(item)==2:
 price_amazon_0="Rs-"+item[i+0].find('span', 'a-offscreen').text[1:]

 price_amazon_1="Rs-"+item[i+1].find('span', 'a-offscreen').text[1:]





 pp=item[i].find_all('span',{'class':'a-size-medium'})
 try:
  name_amazon_0=pp[0].text
 except:
   pp=item[i].find_all('span',{'class':'a-size-base-plus'})
   name_amazon_0=pp[0].text
 pp=item[i+1].find_all('span',{'class':'a-size-medium'})
 try:
  name_amazon_1=pp[0].text
 except:
   pp=item[i+1].find_all('span',{'class':'a-size-base-plus'})
   name_amazon_1=pp[0].text


 

 image_tag=item[i+0].find_all('img',{'class':'s-image'})
 image_amazon_0=image_tag[0].get('src')
 image_tag=item[i+1].find_all('img',{'class':'s-image'})


 image_amazon_2=image_tag[0].get('src')


 pp=item[i+0].find_all('span',{'class':'a-size-base'})
 rating_amazon=pp[0].text
 rating_amazon_0="("+ rating_amazon + ")"
 pp=item[i+1].find_all('span',{'class':'a-size-base'})

 rating_amazon=pp[0].text
 rating_amazon_1="("+ rating_amazon + ")"

 pp=item[i+0].find_all('span',{'class':'a-icon-alt'})
 star_amazon_0=pp[0].text[0:4]
 pp=item[i+1].find_all('span',{'class':'a-icon-alt'})

 star_amazon_1=pp[0].text[0:4]

 price_amazon_2="item not found"
 name_amazon_2="item not found"
 image_amazon_2="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_amazon_2="item not found"
 star_amazon_2="item not found"
elif len(item)==1:
 price_amazon_0="Rs-"+item[i+0].find('span', 'a-offscreen').text[1:]






 pp=item[i].find_all('span',{'class':'a-size-medium'})
 try:
  name_amazon_0=pp[0].text
 except:
   pp=item[i].find_all('span',{'class':'a-size-base-plus'})
   name_amazon_0=pp[0].text



 image_tag=item[i+0].find_all('img',{'class':'s-image'})
 image_amazon_0=image_tag[0].get('src')



 pp=item[i+0].find_all('span',{'class':'a-size-base'})
 rating_amazon=pp[0].text
 rating_amazon_0="("+ rating_amazon + ")"


 pp=item[i+0].find_all('span',{'class':'a-icon-alt'})
 star_amazon_0=pp[0].text[0:4]

 price_amazon_2="item not found"
 name_amazon_2="item not found"
 image_amazon_2="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_amazon_2="item not found"
 star_amazon_2="item not found"
 price_amazon_1="item not found"
 name_amazon_1="item not found"
 image_amazon_1="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_amazon_1="item not found"
 star_amazon_1="item not found"
 
 


else:
  price_amazon_0="item not found"
  name_amazon_0="item not found"
  image_amazon_0="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
  rating_amazon_0="item not found"
  star_amazon_0="item not found"
  price_amazon_2="item not found"
  name_amazon_2="item not found"
  image_amazon_2="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
  rating_amazon_2="item not found"
  star_amazon_2="item not found"
  price_amazon_1="item not found"
  name_amazon_1="item not found"
  image_amazon_1="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
  rating_amazon_1="item not found"
  star_amazon_1="item not found"




"""#SNAPDEAL EXTRACTION"""

base1="https://www.snapdeal.com/"
def get_url(search_term1):

    template='https://www.snapdeal.com/search?keyword={}&sort=rlvncy'
    search_term1=search_term1.replace(' ','+')
    return template.format(search_term1)
url=get_url(a)
url_snapdeal=url

response=requests.get(url)
html=response.content

"""#CREATING SOUP FOR SNAPDEAL"""

soup1=bs(html,"html.parser")
item=soup1.find_all('div',{'data-js-pos':'0'})
if len(item)>=3:
 atag1=item[0].a
 des=atag1.text.strip()
 url=atag1.get('href')
 price_snapdeal_0="Rs-"+item[0].find('span', 'lfloat product-price').text[5:]

 atag1=item[1].a
 des=atag1.text.strip()
 url=atag1.get('href')
 price_snapdeal_0="Rs-"+item[1].find('span', 'lfloat product-price').text[5:]

 atag1=item[2].a
 des=atag1.text.strip()
 url=atag1.get('href')
 price_snapdeal_2="Rs-"+item[2].find('span', 'lfloat product-price').text[5:]


 pp=item[0].find_all('p',{'class':'product-title'})
 name_snapdeal_0=pp[0].text
 pp=item[1].find_all('p',{'class':'product-title'})

 name_snapdeal_1=pp[0].text
 pp=item[2].find_all('p',{'class':'product-title'})

 name_snapdeal_2=pp[0].text
 pp=item[0].find_all('img',{'class':'product-image'})
 image_snapdeal_0=pp[0].get('src')
 pp=item[1].find_all('img',{'class':'product-image'})

 image_snapdeal_1=pp[0].get('src')
 pp=item[2].find_all('img',{'class':'product-image'})

 image_snapdeal_2=pp[0].get('src')
 pp=item[0].find_all('p',{'class':'product-rating-count'})
 rating_snapdeal_0=pp[0].text
 pp=item[1].find_all('p',{'class':'product-rating-count'})

 rating_snapdeal_1=pp[0].text
 pp=item[2].find_all('p',{'class':'product-rating-count'})

 rating_snapdeal_2=pp[0].text

 pp=item[0].find_all('div',{'class':'filled-stars'})
 star_snapdeal_0=float(pp[0].get('style')[6:10])/20
 pp=item[1].find_all('div',{'class':'filled-stars'})

 star_snapdeal_1=float(pp[0].get('style')[6:10])/20
 pp=item[2].find_all('div',{'class':'filled-stars'})

 star_snapdeal_2=float(pp[0].get('style')[6:10])/20

elif len(item)==2:
 atag1=item[0].a
 des=atag1.text.strip()
 url=atag1.get('href')
 price_snapdeal_0="Rs-"+item[0].find('span', 'lfloat product-price').text[5:]

 atag1=item[1].a
 des=atag1.text.strip()
 url=atag1.get('href')
 price_snapdeal_0="Rs-"+item[1].find('span', 'lfloat product-price').text[5:]




 pp=item[0].find_all('p',{'class':'product-title'})
 name_snapdeal_0=pp[0].text
 pp=item[1].find_all('p',{'class':'product-title'})

 name_snapdeal_1=pp[0].text

 pp=item[0].find_all('img',{'class':'product-image'})
 image_snapdeal_0=pp[0].get('src')
 pp=item[1].find_all('img',{'class':'product-image'})

 

 image_snapdeal_2=pp[0].get('src')
 pp=item[0].find_all('p',{'class':'product-rating-count'})
 rating_snapdeal_0=pp[0].text
 pp=item[1].find_all('p',{'class':'product-rating-count'})



 rating_snapdeal_2=pp[0].text

 pp=item[0].find_all('div',{'class':'filled-stars'})
 star_snapdeal_0=float(pp[0].get('style')[6:10])/20
 pp=item[1].find_all('div',{'class':'filled-stars'})

 star_snapdeal_1=float(pp[0].get('style')[6:10])/20


 price_snapdeal_2="item not found"
 name_snapdeal_2="item not found"
 image_snapdeal_2="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_snapdeal_2="item not found"
 star_snapdeal_2="item not found"

 
elif len(item)==1:
 atag1=item[0].a
 des=atag1.text.strip()
 url=atag1.get('href')
 price_snapdeal_0="Rs-"+item[0].find('span', 'lfloat product-price').text[5:]



 pp=item[0].find_all('p',{'class':'product-title'})
 name_snapdeal_0=pp[0].text


 pp=item[0].find_all('img',{'class':'product-image'})
 image_snapdeal_0=pp[0].get('src')


 pp=item[0].find_all('p',{'class':'product-rating-count'})
 rating_snapdeal_0=pp[0].text


 pp=item[0].find_all('div',{'class':'filled-stars'})
 star_snapdeal_0=float(pp[0].get('style')[6:10])/20




 price_snapdeal_2="item not found"
 name_snapdeal_2="item not found"
 image_snapdeal_2="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_snapdeal_2="item not found"
 star_snapdeal_2="item not found"
 price_snapdeal_1="item not found"
 name_snapdeal_1="item not found"
 image_snapdeal_1="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_snapdeal_1="item not found"
 star_snapdeal_1="item not found"
else:
  price_snapdeal_0="item not found"
  name_snapdeal_0="item not found"
  image_snapdeal_0="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
  rating_snapdeal_0="item not found"
  star_snapdeal_0="item not found"
  price_snapdeal_2="item not found"
  name_snapdeal_2="item not found"
  image_snapdeal_2="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
  rating_snapdeal_2="item not found"
  star_snapdeal_2="item not found"
  price_snapdeal_1="item not found"
  name_snapdeal_1="item not found"
  image_snapdeal_1="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
  rating_snapdeal_1="item not found"
  star_snapdeal_1="item not found"











"""#DATA EXTRACTION FOR FLIPKART"""

base2="www.flipkart.com"
def get_url(search_term):
    template='https://www.flipkart.com/search?q={}'
    search_term=search_term.replace(' ','+')
    return template.format(search_term)
url=get_url(a)
url_flipkart=url

response=requests.get(url)
html=response.content

"""#CREATING SOUP FOR FLIPKART"""

soup2=bs(html,'html.parser')
results=soup2.find_all('div',{'class':'_13oc-S'})

if len(results)>=3:

 item=results[0]
 atag3=item.a
 des=atag3.text.strip()
 url=base2+atag3.get('href')
 url1="https://"+url
 response=requests.get(url1)


 html1=response.content
 soup3=bs(html1,'html.parser')
 item=soup3.find_all('div', {'class':'_30jeq3'})
 price_flipkart_0="Rs-"+ item[0].text[1:]

 pp=soup3.find_all('a',{'class':'s1Q9rs'})
 name_flipkart_0=pp[0].text

 pp=soup3.find_all('img',{'class':'_396cs4'})
 image_flipkart_0=pp[0].get('src')

 pp=soup3.find_all('span',{'class':'_2_R_DZ'})
 rating_flipkart_0=pp[0].text



 pp=soup3.find_all('div',{'class':'_3LWZlK'})
 star_flipkart_0=pp[0].text

 item = results[1]
 atag3 = item.a
 des = atag3.text.strip()
 url = base2 + atag3.get('href')
 url1 = "https://" + url
 response = requests.get(url1)

 html1 = response.content
 soup3 = bs(html1, 'html.parser')
 item = soup3.find_all('div', {'class': '_30jeq3'})
 price_flipkart_1 = "Rs-" + item[0].text[1:]

 pp = soup3.find_all('a', {'class': 's1Q9rs'})
 name_flipkart_1= pp[0].text

 pp = soup3.find_all('img', {'class': '_396cs4'})
 image_flipkart_1 = pp[0].get('src')

 pp = soup3.find_all('span', {'class': '_2_R_DZ'})
 rating_flipkart_1 = pp[0].text

 pp = soup3.find_all('div', {'class': '_3LWZlK'})
 star_flipkart_1 = pp[0].text

 item = results[2]
 atag3 = item.a
 des = atag3.text.strip()
 url = base2 + atag3.get('href')
 url1 = "https://" + url
 response = requests.get(url1)

 html1 = response.content
 soup3 = bs(html1, 'html.parser')
 item = soup3.find_all('div', {'class': '_30jeq3'})
 price_flipkart_2= "Rs-" + item[0].text[1:]

 pp = soup3.find_all('a', {'class': 's1Q9rs'})
 name_flipkart_2= pp[0].text

 pp = soup3.find_all('img', {'class': '_396cs4'})
 image_flipkart_2 = pp[0].get('src')

 pp = soup3.find_all('span', {'class': '_2_R_DZ'})
 rating_flipkart_2 = pp[0].text

 pp = soup3.find_all('div', {'class': '_3LWZlK'})
 star_flipkart_2 = pp[0].text

elif len(item)==2:
 item=results[0]
 atag3=item.a
 des=atag3.text.strip()
 url=base2+atag3.get('href')
 url1="https://"+url
 response=requests.get(url1)


 html1=response.content
 soup3=bs(html1,'html.parser')
 item=soup3.find_all('div', {'class':'_30jeq3'})
 price_flipkart_0="Rs-"+ item[0].text[1:]

 pp=soup3.find_all('a',{'class':'s1Q9rs'})
 name_flipkart_0=pp[0].text

 pp=soup3.find_all('img',{'class':'_396cs4'})
 image_flipkart_0=pp[0].get('src')

 pp=soup3.find_all('span',{'class':'_2_R_DZ'})
 rating_flipkart_0=pp[0].text



 pp=soup3.find_all('div',{'class':'_3LWZlK'})
 star_flipkart_0=pp[0].text

 item = results[1]
 atag3 = item.a
 des = atag3.text.strip()
 url = base2 + atag3.get('href')
 url1 = "https://" + url
 response = requests.get(url1)

 html1 = response.content
 soup3 = bs(html1, 'html.parser')
 item = soup3.find_all('div', {'class': '_30jeq3'})
 price_flipkart_1 = "Rs-" + item[0].text[1:]

 pp = soup3.find_all('a', {'class': 's1Q9rs'})
 name_flipkart_1= pp[0].text

 pp = soup3.find_all('img', {'class': '_396cs4'})
 image_flipkart_1 = pp[0].get('src')

 pp = soup3.find_all('span', {'class': '_2_R_DZ'})
 rating_flipkart_1 = pp[0].text

 pp = soup3.find_all('div', {'class': '_3LWZlK'})
 star_flipkart_1 = pp[0].text
 price_flipkart_2="item not found"
 name_flipkart_2="item not found"
 image_flipkart_2="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_flipkart_2="item not found"
 star_flipkart_2="item not found"
elif len(item)==1:
 item=results[0]
 atag3=item.a
 des=atag3.text.strip()
 url=base2+atag3.get('href')
 url1="https://"+url
 response=requests.get(url1)


 html1=response.content
 soup3=bs(html1,'html.parser')
 item=soup3.find_all('div', {'class':'_30jeq3'})
 price_flipkart_0="Rs-"+ item[0].text[1:]

 pp=soup3.find_all('a',{'class':'s1Q9rs'})
 name_flipkart_0=pp[0].text

 pp=soup3.find_all('img',{'class':'_396cs4'})
 image_flipkart_0=pp[0].get('src')

 pp=soup3.find_all('span',{'class':'_2_R_DZ'})
 rating_flipkart_0=pp[0].text



 pp=soup3.find_all('div',{'class':'_3LWZlK'})
 star_flipkart_0=pp[0].text
 price_flipkart_2="item not found"
 name_flipkart_2="item not found"
 image_flipkart_2="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_flipkart_2="item not found"
 star_flipkart_2="item not found"
 price_flipkart_1="item not found"
 name_flipkart_1="item not found"
 image_flipkart_1="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_flipkart_1="item not found"
 star_flipkart_1="item not found"
else:

 price_flipkart_2="item not found"
 name_flipkart_2="item not found"
 image_flipkart_2="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_flipkart_2="item not found"
 star_flipkart_2="item not found"
 price_flipkart_1="item not found"
 name_flipkart_1="item not found"
 image_flipkart_1="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_flipkart_1="item not found"
 star_flipkart_1="item not found"
 price_flipkart_0="item not found"
 name_flipkart_0="item not found"
 image_flipkart_0="https://www.google.com/url?sa=i&url=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3AForbidden_Symbol_Transparent.svg&psig=AOvVaw0yZNFO7EuZFeSrgI5dUc6c&ust=1626266430569000&source=images&cd=vfe&ved=0CAoQjRxqFwoTCLj2wdmI4PECFQAAAAAdAAAAABAD"
 rating_flipkart_0="item not found"
 star_flipkart_0="item not found"





print(price_amazon_0)
print(name_amazon_0)
print(image_amazon_0)
print(rating_amazon_0)
print(star_amazon_0)
print(price_snapdeal_0)
print(name_snapdeal_0)
print(image_snapdeal_0)
print(rating_snapdeal_0)
print(star_snapdeal_0)
print(price_flipkart_0)
print(name_flipkart_0)
print(image_flipkart_0)
print(rating_flipkart_0)
print(star_flipkart_0)

print(price_amazon_1)
print(name_amazon_1)
print(image_amazon_1)
print(rating_amazon_1)
print(star_amazon_1)
print(price_snapdeal_1)
print(name_snapdeal_1)
print(image_snapdeal_1)
print(rating_snapdeal_1)
print(star_snapdeal_1)
print(price_flipkart_1)
print(name_flipkart_1)
print(image_flipkart_1)
print(rating_flipkart_1)
print(star_flipkart_1)

print(price_amazon_2)
print(name_amazon_2)
print(image_amazon_2)
print(rating_amazon_2)
print(star_amazon_2)
print(price_snapdeal_2)
print(name_snapdeal_2)
print(image_snapdeal_2)
print(rating_snapdeal_2)
print(star_snapdeal_2)
print(price_flipkart_2)
print(name_flipkart_2)
print(image_flipkart_2)
print(rating_flipkart_2)
print(star_flipkart_2)
# Out:
# enter the product nameyamaha guitar
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-4be2b61c4f23> in <module>()
#     492
#     493  pp = soup3.find_all('a', {'class': 's1Q9rs'})
# --> 494  name_flipkart_1= pp[0].text
#     495
#     496  pp = soup3.find_all('img', {'class': '_396cs4'})
#
# IndexError: list index out of range
